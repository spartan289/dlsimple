# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\student\Downloads\pima-indians-diabetes.csv',header=None)

# %%
data
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
y = data.iloc[:,8]
X = data.iloc[:,:8]

# %%
X
# Out:
#       0    1   2   3    4     5      6   7
# 0     6  148  72  35    0  33.6  0.627  50
# 1     1   85  66  29    0  26.6  0.351  31
# 2     8  183  64   0    0  23.3  0.672  32
# 3     1   89  66  23   94  28.1  0.167  21
# 4     0  137  40  35  168  43.1  2.288  33
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 763  10  101  76  48  180  32.9  0.171  63
# 764   2  122  70  27    0  36.8  0.340  27
# 765   5  121  72  23  112  26.2  0.245  30
# 766   1  126  60   0    0  30.1  0.349  47
# 767   1   93  70  31    0  30.4  0.315  23
#
# [768 rows x 8 columns]

# %%
X.shape
# Out:
# (768, 8)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
ann = Sequential()
ann.add(Dense(units=11,activation='relu'))
ann.add(Dense(units=15,activation='relu'))

ann.add(Dense(units=1,activation='sigmoid'))
opt = tf.keras.optimizers.Adam()
loss = tf.keras.losses.BinaryCrossentropy()
ann.compile(loss= loss
            ,optimizer=opt,
            metrics=['accuracy'])
h = ann.fit(X_train, y_train, batch_size = 50, validation_data = (X_test,y_test), epochs = 100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 11ms/step - loss: 0.7178 - accuracy: 0.4121 - val_loss: 0.6983 - val_accuracy: 0.4545
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.5391 - val_loss: 0.6743 - val_accuracy: 0.6299
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.6938 - val_loss: 0.6551 - val_accuracy: 0.6948
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6445 - accuracy: 0.7296 - val_loss: 0.6389 - val_accuracy: 0.6948
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6264 - accuracy: 0.7427 - val_loss: 0.6234 - val_accuracy: 0.7078
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6092 - accuracy: 0.7394 - val_loss: 0.6061 - val_accuracy: 0.7078
# Epoch 7/100
# ...

# %%
ann.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_69 (Dense)            (None, 11)                132
#
#  dense_70 (Dense)            (None, 15)                180
#
#  dense_71 (Dense)            (None, 9)                 144
#
# ...
# Total params: 456
# Trainable params: 456
# Non-trainable params: 0
# _________________________________________________________________
